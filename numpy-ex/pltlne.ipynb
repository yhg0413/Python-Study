# %%
import matplotlib.pyplot as plt #쥬피터는 혼자 실행하기용이지 개발용은 아님
import numpy as np

# %% [markdown]
# ## 기본적인 선 그래프 그리기
#  - plt.plot([x, ],y[, fmt]) #대괄호는 생략해도 되는 내용
#  - x: x축 좌표의 값 시퀀스 데이터
#  - y : y 축 좌표의 값 시퀀스 데이터
#  - fmt : format string

# %%
data1 = [10,14,19,20,25]

# %%
plt.plot(data1)
plt.show()

# %%
x = np.arange(-4.5,5,0.5) #배열 x 생성. 범위 [-4.5,5), 0.5.씩 증가
y = 2*x**2 # 수식을 이용해 배열 x에 대응하는 배영 y 생성
[x,y]
# Out:
# [array([-4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,
#          1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5]),
#  array([40.5, 32. , 24.5, 18. , 12.5,  8. ,  4.5,  2. ,  0.5,  0. ,  0.5,
#          2. ,  4.5,  8. , 12.5, 18. , 24.5, 32. , 40.5])]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 하나의 그래프 창에 여러개의 데이터를 선 그래프로 표시하는 방법

# %%
x = np.arange(-4.5, 5, 0.5)
y1 = 2*x**2
y2 = 5*x + 30
y3 = 4*x**2 + 10

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %%
plt.plot(x, y1, x,y2, x,y3)
plt.show()

# %% [markdown]
# ## 여러 그래프 그리기

# %%
plt.plot(x,y1) # 처음 그리기 함수를 수행하면 그래프 창이 자동으로 생성됨
plt.figure() # 새로운 그래프 창을 생성함
plt.plot(x,y2)
plt.show()

# %% [markdown]
# plt.figure(n)
# - n번째 새로운 그래프 창을 생성
# - 이미 생성되어 있으면 해당 그래프 창이 선택됨
# - 이후의 plot()은 n번째 그래프 창에 그려짐

# %%
#데이터 생성
x = np.arange(-5,5,0.1)
y1 = x**2 -2
y2 = 20*np.cos(x)**2 # Numpy에서 cos()는 np.cos()으로 입력

plt.figure(1)       # 1번 그래프 창을 생성함
plt.plot(x, y1)     # 지정된 그래프 창에 그래프를 그림

plt.figure(2)       # 2번 그래프 창을 생성함
plt.plot(x, y2)     # 지정된 그래프 창에 그래프를 그림

plt.figure(1)       # 이미 생성된 1번 그래프 창을 지정함
plt.plot(x, y2)     # 지정된 그래프 창에 그래프를 그림

plt.figure(2)       # 이미 생성된 2번 그래프 창을 지정함
plt.clf()           # 2번 그래프 창에 그려진 모든 그래프를 지움
plt.plot(x, y1)     # 지정된 그래프 창에 그래프를 그림

plt.show()

# %% [markdown]
# ## 하나의 그래프 창을 분할하여 사용하기
#  plt.subplot(m, n, p)
#  - m x n 행렬로 이뤄진 하위 그래프 중에서 p번 위치(1부터 시작)에 그래프 창 지정

# %%
# 데이터 생성
x = np.arange(0, 10, 0.1)
y1 = 0.3 * x-5 ** 2 + 1
y2 = -1.5*x + 3
y3 = np.sin(x) ** 2 # NumPy에서 sin()는 np.sin()으로 입력
y4 = 10*np.exp(-x) + 1 #NumPy에서 exp()는 np.exp()로 입력

# 2x2 핼렬로 이뤄진 하위 그래프에서 p에 따라 위치를 지정
plt.subplot(2,2,1) # p는 1
plt.plot(x,y1)

plt.subplot(2,2,2) # p는 2
plt.plot(x,y2)

plt.subplot(2,2,3) # p는 3
plt.plot(x,y3)

plt.subplot(2,2,4) # p는 4
plt.plot(x,y4)

plt.show()

# %% [markdown]
# ## 출력 범위 지정하기
#  - plt.xlim(xmin, xmax) # x축의 좌표 범위 지정
#  - plt.ylim(ymin, ymas) # y축의 좌표 범위 지정
# ## 현재 출력 범위 얻기
#  - [xmin, xmax] = pit.xlim()
#  - [ymin, ymax] = pit.ylim()

# %%
x = np.linspace(-4,4,100) # [-4,4] 범위에서 100개의 값 생성
y1 = x**3
y2 = 10*x**2-2

plt.plot(x,y1,x,y2)
plt.show()

# %%
plt.plot(x,y1,x,y2)
plt.xlim(-1,1)
plt.ylim(-3,3)
plt.show()  #x부분 y 부분 확대해서 보넋

# %% [markdown]
# ## 출력 형식 지정
#  - fmt = '[color][line_style][marker]'
#  - color : b,g,r,c,m,y,k,w
#  - line_style : -(실선), --(파선), : (점선), -.(파선점선 혼합선)
#  - marker 이건 그림 봐야함

# %%
x = np.arange(0,5,1)
y1 = x
y2 = x+1
y3 = x+2
y4 = x+3
plt.plot(x, y1, x, y2,x, y3,x ,y4) #디폴트로 색 배정 된거임
plt.show()

# %%
plt.plot(x, y1,'m', x, y2,'y',x, y3,'k',x ,y4,'c') #바꾼거
plt.show()

# %%
plt.plot(x, y1,'-', x, y2,'--',x, y3,':',x ,y4,'-.') #바꾼거
plt.show()

# %%
plt.plot(x, y1,'o', x, y2,'^',x, y3,'s',x ,y4,'d') #바꾼거
plt.show()

# %%
plt.plot(x, y1,'>--r', x, y2,'s-g',x, y3,'d:b',x ,y4,'-.Xc') #바꾼거
plt.show()

# %% [markdown]
# ## 라벨, 제목, 격자, 범례, 문자열 표시
#  - plt.xlabel(문자열)
#  - plt.ylabel(문자열)
#  - plt.title(str)
#  - plt.grid(True) # plt.grid() - 격자 출력
# #### 한글을 사용할려면 내가 사용할 한글폰트위 위치를 참조해야함

# %%
x = np.arange(-4.5, 5, 0.5)
y = 2*x**3
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Graph title")
plt.grid(True) # = plt.grid()
plt.show()

# %% [markdown]
# - plt.legend(['str1', 'str2', … ]) # 범례
# - plt.legend(['str1', 'str2', … ], loc=위치) # 범례 위치
#  - best 0
#  - upper right 1
#  - upper left 2
#  - lower left 3
#  - lowr right 4
#  - right 5
#  - center left 6
#  - center right 7
#  - lower center 8
#  - upper center 9
#  - center 10

# %%
x = np.arange(0,5,1)
y1 =x
y2 = x+1
y3 = x+2
y4 = x+3
plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.legend(['data1', 'data2' , 'data3', 'data4'])
plt.show()

# %%
plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.legend(['data1', 'data2', 'data3', 'data4'], loc = 4)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Graph title')
plt.grid(True)

# %%
# 한글 출력 하기
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' #맑은 고딕으로 설정
                    #사전임 딕 쎤
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.legend(['데이터1', '데이터2', '데이터3', '데이터4'], loc = 4)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Graph title')
plt.grid(True)

# %% [markdown]
# 임의의 문자열 출력
#  - plt.text(x,y,'문자열'

# %%
plt.plot(x, y1, '>--r', x, y2, 's-g', x, y3, 'd:b', x, y4, '-.Xc')
plt.text(0,6, "문자열 출력 1")
plt.text(0,5, "문자열 출력 2")
plt.text(3,1, "문자열 출력 3") 
plt.text(3,0, "문자열 출력 4") #출력될시 x와 y에 값에 프린트됌
plt.show()
